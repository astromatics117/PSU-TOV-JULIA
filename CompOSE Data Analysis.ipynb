# %% [markdown]
# This file is the most up to date with the CompOSE data.

# %%
using DelimitedFiles
using Plots

# %%
#Density vs Sound Speed Linear
#Geometric Units 

mₙ = 939.565413

nb = readdlm("eos.nb RG(SKb)", skipstart = 2)
data = readdlm("eos.thermo RG(SKb)", skipstart = 1)
Q1 = data[:,4];
Q7 = data[:,10];

P = Q1.*nb;
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1];
dρ = ρ[2:end] - ρ[1:end-1];

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plotlyjs()
plot(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), xlabel = "ρ", ylabel = "cₛ²", label = "RG(SKb)", title = "Density v. Sound Speed")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BFH(QHC19-A)", skipstart = 2)
data = readdlm("eos.thermo BFH(QHC19-A)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]

P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "BFH(QHC19-A)")

########################################################################################################################

mₙ = 938.918713

nb = readdlm("eos.nb DNS(CMF)", skipstart = 2)
data = readdlm("eos.thermo DNS(CMF)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "DNS(CMF)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SkI3)", skipstart = 2)
data = readdlm("eos.thermo RG(SkI3)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "RG(SkI3)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb JJ(VQCD(APR))", skipstart = 2)
data = readdlm("eos.thermo JJ(VQCD(APR))", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "JJ(VQCD(APR))")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BHK(QHC18)", skipstart = 2)
data = readdlm("eos.thermo BHK(QHC18)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "BHK(QHC18)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-5", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-5", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "DS(CMF)-5")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SLY2)", skipstart = 2)
data = readdlm("eos.thermo RG(SLY2)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "RG(SLY2)")

########################################################################################################################

mₙ = 939.565350

nb = readdlm("eos.nb GMSR(H7)", skipstart = 2)
data = readdlm("eos.thermo GMSR(H7)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "GMSR(H7)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-1", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-1", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xlims = (1.e-4, 1.e-1), ylims = (0., 1.), label = "DS(CMF)-1")
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-9092503968219018760\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-12798712588889925533\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...

# %%
#Density vs Sound Speed Logged
#Geometric units

mₙ = 939.565413

nb = readdlm("eos.nb RG(SKb)", skipstart = 2)
data = readdlm("eos.thermo RG(SKb)", skipstart = 1)
Q1 = data[:,4];
Q7 = data[:,10];

P = Q1.*nb;
ρ = (Q7 .+ 1) .* (nb .* mₙ);

dP = P[2:end] - P[1:end-1];
dρ = ρ[2:end] - ρ[1:end-1];

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plotlyjs()
plot(ρ[2:end].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "RG(SKb)", xlabel = "ρ", ylabel = "cₛ²",  title = "Density v. Sound Speed")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BFH(QHC19-A)", skipstart = 2)
data = readdlm("eos.thermo BFH(QHC19-A)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]

P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[2:end].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "BFH(QHC19-A)")

########################################################################################################################

mₙ = 938.918713

nb = readdlm("eos.nb DNS(CMF)", skipstart = 2)
data = readdlm("eos.thermo DNS(CMF)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[2:end].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "DNS(CMF)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SkI3)", skipstart = 2)
data = readdlm("eos.thermo RG(SkI3)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "RG(SkI3)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb JJ(VQCD(APR))", skipstart = 2)
data = readdlm("eos.thermo JJ(VQCD(APR))", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "JJ(VQCD(APR))")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BHK(QHC18)", skipstart = 2)
data = readdlm("eos.thermo BHK(QHC18)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "BHK(QHC18)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-5", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-5", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "DS(CMF)-5")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SLY2)", skipstart = 2)
data = readdlm("eos.thermo RG(SLY2)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "RG(SLY2)")

########################################################################################################################

mₙ = 939.565350

nb = readdlm("eos.nb GMSR(H7)", skipstart = 2)
data = readdlm("eos.thermo GMSR(H7)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "GMSR(H7)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-1", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-1", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

dP = P[2:end] - P[1:end-1]
dρ = ρ[2:end] - ρ[1:end-1]

sound_speed = (abs.(dP ./ dρ));
geo_conv = (1.6191004251588869e-18)*(1782700000000.0002);

plot!(ρ[1:end - 1].*geo_conv, sound_speed, xaxis = :log, yaxis = :log, label = "DS(CMF)-1")
# Out:
#     <div id="dc0fde48-a721-497c-bb70-2592e55d33f6" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('dc0fde48-a721-497c-bb70-2592e55d33f6');
#     Plotly.plot(PLOT, [
#     {
#         "colorbar": {
#             "title": ""
#         },
#         "y": [
#             0.0003021460385484557,
#             0.0003042651196867309,
#             0.00030689827088314415,
#             0.00030808686643911073,
#             0.0003116825495301578,
#             0.0003138659156425726,
#             0.0003165702531590876,
#             0.00031777792412758304,
#             0.00032023085304894725,
#             0.0003239645903986615,
#             0.0003251940820257734,
#             0.0003289881236989827,
#             0.0003302367586276652,
# ...

# %%
#Density vs Pressure Linear
#No units specified

mₙ = 939.565413

nb = readdlm("eos.nb RG(SKb)", skipstart = 2)
data = readdlm("eos.thermo RG(SKb)", skipstart = 1)
Q1 = data[:,4];
Q7 = data[:,10];

P = Q1.*nb;
ρ = (Q7 .+ 1) .* (nb .* mₙ);

plotlyjs()
plot(ρ, P, label = "RG(SKb)", ylabel = "P", xlabel = "ρ",  title = "Density v. Pressure")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BFH(QHC19-A)", skipstart = 2)
data = readdlm("eos.thermo BFH(QHC19-A)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]

P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "BFH(QHC19-A)")

########################################################################################################################

mₙ = 938.918713

nb = readdlm("eos.nb DNS(CMF)", skipstart = 2)
data = readdlm("eos.thermo DNS(CMF)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "DNS(CMF)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SkI3)", skipstart = 2)
data = readdlm("eos.thermo RG(SkI3)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "RG(SkI3)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb JJ(VQCD(APR))", skipstart = 2)
data = readdlm("eos.thermo JJ(VQCD(APR))", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "JJ(VQCD(APR))")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BHK(QHC18)", skipstart = 2)
data = readdlm("eos.thermo BHK(QHC18)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "BHK(QHC18)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-5", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-5", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "DS(CMF)-5")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SLY2)", skipstart = 2)
data = readdlm("eos.thermo RG(SLY2)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "RG(SLY2)")

########################################################################################################################

mₙ = 939.565350

nb = readdlm("eos.nb GMSR(H7)", skipstart = 2)
data = readdlm("eos.thermo GMSR(H7)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "GMSR(H7)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-1", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-1", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, label = "DS(CMF)-1")
# Out:
#     <div id="044f6bf9-b80a-432a-9b36-7147a9e1c918" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('044f6bf9-b80a-432a-9b36-7147a9e1c918');
#     Plotly.plot(PLOT, [
#     {
#         "colorbar": {
#             "title": ""
#         },
#         "y": [
#             2.070205e-8,
#             2.135729e-8,
#             2.20325e-8,
#             2.272942e-8,
#             2.344534e-8,
#             2.418649e-8,
#             2.495022e-8,
#             2.573848e-8,
#             2.654821e-8,
#             2.738318e-8,
#             2.824755e-8,
#             2.9135460000000004e-8,
#             3.005462e-8,
#             3.09988e-8,
#             3.197238e-8,
#             3.298022e-8,
#             3.401548e-8,
#             3.508294e-8,
# ...

# %%
#Density vs Pressure Logged
#No units specified

mₙ = 939.565413

nb = readdlm("eos.nb RG(SKb)", skipstart = 2)
data = readdlm("eos.thermo RG(SKb)", skipstart = 1)
Q1 = data[:,4];
Q7 = data[:,10];

P = Q1.*nb;
ρ = (Q7 .+ 1) .* (nb .* mₙ);

plotlyjs()
plot(ρ, P, xaxis = :log, yaxis = :log, label = "RG(SKb)", ylabel = "P", xlabel = "ρ",  title = "Density vs Pressure")
########################################################################################################################


mₙ = 939.565000

nb = readdlm("eos.nb BFH(QHC19-A)", skipstart = 2)
data = readdlm("eos.thermo BFH(QHC19-A)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]

P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "BFH(QHC19-A)")

########################################################################################################################

mₙ = 938.918713

nb = readdlm("eos.nb DNS(CMF)", skipstart = 2)
data = readdlm("eos.thermo DNS(CMF)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "DNS(CMF)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SkI3)", skipstart = 2)
data = readdlm("eos.thermo RG(SkI3)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "RG(SkI3)")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb JJ(VQCD(APR))", skipstart = 2)
data = readdlm("eos.thermo JJ(VQCD(APR))", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "JJ(VQCD(APR))")

########################################################################################################################

mₙ = 939.565000

nb = readdlm("eos.nb BHK(QHC18)", skipstart = 2)
data = readdlm("eos.thermo BHK(QHC18)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "BHK(QHC18)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-5", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-5", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "DS(CMF)-5")

########################################################################################################################

mₙ = 939.565330

nb = readdlm("eos.nb RG(SLY2)", skipstart = 2)
data = readdlm("eos.thermo RG(SLY2)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "RG(SLY2)")

########################################################################################################################

mₙ = 939.565350

nb = readdlm("eos.nb GMSR(H7)", skipstart = 2)
data = readdlm("eos.thermo GMSR(H7)", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "GMSR(H7)")

########################################################################################################################

mₙ = 938.918712

nb = readdlm("eos.nb DS(CMF)-1", skipstart = 2)
data = readdlm("eos.thermo DS(CMF)-1", skipstart = 1)
Q1 = data[:,4]
Q7 = data[:,10]
P = Q1.*nb
ρ = (Q7 .+ 1) .* (nb .* mₙ)

plot!(ρ, P, xaxis = :log, yaxis = :log, label = "DS(CMF)-1")
# Out:
#     <div id="4900b6b1-a01c-48bc-a82a-14c065929a86" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('4900b6b1-a01c-48bc-a82a-14c065929a86');
#     Plotly.plot(PLOT, [
#     {
#         "colorbar": {
#             "title": ""
#         },
#         "y": [
#             2.070205e-8,
#             2.135729e-8,
#             2.20325e-8,
#             2.272942e-8,
#             2.344534e-8,
#             2.418649e-8,
#             2.495022e-8,
#             2.573848e-8,
#             2.654821e-8,
#             2.738318e-8,
#             2.824755e-8,
#             2.9135460000000004e-8,
#             3.005462e-8,
#             3.09988e-8,
#             3.197238e-8,
#             3.298022e-8,
#             3.401548e-8,
#             3.508294e-8,
# ...
